# %%
import threading
def main(r,msg):
    for i in range(1,r+1):
        print(msg)
x=threading.Thread(target=main,args=(5,"hello",))
x.start()
y=threading.Thread(target=main,args=(6,"welcome"))
y.start()
# Out:
# hello
# hello
# hello
# hello
# hello
# welcome
# welcome
# welcome
# welcome
# welcome
# welcome
